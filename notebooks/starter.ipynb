# %% [markdown]
# # Mapping Climate Crises with Python
# ### MLH Global Hack Week — Starter Notebook
#
# In this workshop we'll take the **EM-DAT International Disaster Database** — a real, messy, 16,000+ row dataset — and turn it into an interactive map of climate-related natural disasters.
#
# **Plan:**
# 1. Load and explore the raw data
# 2. Clean and filter it down to what we need
# 3. Explore patterns with pandas
# 4. Build an interactive map with Folium
# 5. Mini challenge — make it your own!
#
# Follow along live — code cells marked `# TODO` are where we'll write code together.

# %% [markdown]
# ## 0. Setup
#
# Get the dataset yourself from [public.emdat.be/data](https://public.emdat.be/data) (free account required). Filter to 2000–2026, leave Classification/Countries blank, leave historical toggle off. Download as `.xlsx` and place it in the `data/` folder.

# %%
# !pip install pandas folium openpyxl -q

# %%
import pandas as pd
import folium

# TODO: load the xlsx file with pd.read_excel
df = pd.read_excel('/content/sample_data/public_emdat_2026-05-25.xlsx')
print(df.shape)
df.head()
# Out:
# (16834, 47)
#           DisNo. Historic Classification Key Disaster Group Disaster Subgroup  \
# 0  2025-0303-ECU       No    nat-geo-ear-gro        Natural       Geophysical
# 1  2026-0153-KEN       No    nat-hyd-flo-flo        Natural      Hydrological
# 2  2025-0750-AFG       No    nat-geo-ear-gro        Natural       Geophysical
# 3  2026-0305-AFG       No    nat-hyd-flo-flo        Natural      Hydrological
# 4  2024-0962-AGO       No    nat-bio-epi-bac        Natural        Biological
#
#   Disaster Type   Disaster Subtype          External IDs Event Name  ISO  ...  \
# 0    Earthquake    Ground movement                   NaN        NaN  ECU  ...
# 1         Flood    Flood (General)                   NaN        NaN  KEN  ...
# 2    Earthquake    Ground movement  GLIDE:EQ-2025-000153        NaN  AFG  ...
# 3         Flood    Flood (General)                   NaN        NaN  AFG  ...
# 4      Epidemic  Bacterial disease  GLIDE:EP-2025-000013    Cholera  AGO  ...
#
#   Reconstruction Costs, Adjusted ('000 US$) Insured Damage ('000 US$)  \
# 0                                       NaN                       NaN
# 1                                       NaN                       NaN
# 2                                       NaN                       NaN
# 3                                       NaN                       NaN
# 4                                       NaN                       NaN
#
#   Insured Damage, Adjusted ('000 US$) Total Damage ('000 US$)  \
# 0                                 NaN                     NaN
# 1                                 NaN                     NaN
# 2                                 NaN                180000.0
# 3                                 NaN                     NaN
# 4                                 NaN                     NaN
#
#   Total Damage, Adjusted ('000 US$)    CPI Admin Units GADM Admin Units  \
# 0                               NaN  100.0         NaN              NaN
# 1                               NaN    NaN         NaN              NaN
# 2                          180000.0  100.0         NaN              NaN
# 3                               NaN    NaN         NaN              NaN
# 4                               NaN  100.0         NaN              NaN
#
#    Entry Date  Last Update
# 0  2025-04-28   2026-05-15
# 1  2026-03-09   2026-05-15
# 2  2025-09-01   2026-05-15
# 3  2026-05-04   2026-05-11
# 4  2025-01-17   2026-05-15
#
# [5 rows x 47 columns]

# %% [markdown]
# ## 1. Explore the mess
#
# 47 columns, 16,834 rows. Let's see what we're working with.

# %%
# TODO: use df.info() to see column types and null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16834 entries, 0 to 16833
# Data columns (total 47 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   DisNo.                                     16834 non-null  object
#  1   Historic                                   16834 non-null  object
#  2   Classification Key                         16834 non-null  object
#  3   Disaster Group                             16834 non-null  object
#  4   Disaster Subgroup                          16834 non-null  object
#  5   Disaster Type                              16834 non-null  object
#  6   Disaster Subtype                           16834 non-null  object
#  7   External IDs                               4379 non-null   object
#  8   Event Name                                 5323 non-null   object
#  9   ISO                                        16834 non-null  object
#  10  Country                                    16834 non-null  object
#  11  Subregion                                  16834 non-null  object
#  12  Region                                     16834 non-null  object
#  13  Location                                   16039 non-null  object
#  14  Origin                                     4318 non-null   object
#  15  Associated Types                           3690 non-null   object
#  16  OFDA/BHA Response                          16834 non-null  object
#  17  Appeal                                     16834 non-null  object
#  18  Declaration                                16834 non-null  object
#  19  AID Contribution ('000 US$)                489 non-null    float64
#  20  Magnitude                                  3392 non-null   float64
#  21  Magnitude Scale                            10581 non-null  object
#  22  Latitude                                   1854 non-null   float64
#  23  Longitude                                  1854 non-null   float64
#  24  River Basin                                1346 non-null   object
#  25  Start Year                                 16834 non-null  int64
#  26  Start Month                                16760 non-null  float64
#  27  Start Day                                  15242 non-null  float64
#  28  End Year                                   16834 non-null  int64
#  29  End Month                                  16664 non-null  float64
#  30  End Day                                    15327 non-null  float64
#  31  Total Deaths                               13557 non-null  float64
#  32  No. Injured                                6323 non-null   float64
#  33  No. Affected                               7841 non-null   float64
#  34  No. Homeless                               1358 non-null   float64
#  35  Total Affected                             12576 non-null  float64
#  36  Reconstruction Costs ('000 US$)            34 non-null     float64
#  37  Reconstruction Costs, Adjusted ('000 US$)  34 non-null     float64
#  38  Insured Damage ('000 US$)                  721 non-null    float64
#  39  Insured Damage, Adjusted ('000 US$)        721 non-null    float64
#  40  Total Damage ('000 US$)                    3327 non-null   float64
#  41  Total Damage, Adjusted ('000 US$)          3313 non-null   float64
#  42  CPI                                        16697 non-null  float64
#  43  Admin Units                                8394 non-null   object
#  44  GADM Admin Units                           7831 non-null   object
#  45  Entry Date                                 16834 non-null  object
#  46  Last Update                                16834 non-null  object
# dtypes: float64(20), int64(2), object(25)
# memory usage: 6.0+ MB

# %%
# TODO: check the 'Disaster Group' column with value_counts()

# %% [markdown]
# We've got two groups: **Natural** disasters (floods, earthquakes, storms...) and **Technological** (industrial accidents, transport accidents).
#
# For "climate crises" we want the Natural ones.

# %%
# TODO: filter df to rows where 'Disaster Group' == 'Natural'
# Store the result as `natural`
natural = df[df['Disaster Group'] == 'Natural'].copy()
print(f"Natural disasters: {len(natural)} rows")
natural['Disaster Type'].value_counts()
# Out:
# Natural disasters: 10762 rows
# Disaster Type
# Flood                          4271
# Storm                          2877
# Epidemic                        894
# Earthquake                      698
# Extreme temperature             568
# Mass movement (wet)             500
# Drought                         424
# Wildfire                        344
# Volcanic activity               133
# Infestation                      29
# Mass movement (dry)              14
# Glacial lake outburst flood       8
# Impact                            1
# Animal incident                   1
# Name: count, dtype: int64

# %% [markdown]
# ## 2. The lat/long problem
#
# To put events on a map we need coordinates. Let's check how many rows actually have them.

# %%
# TODO: count non-null values in 'Latitude' and compute the percentage of `natural` that has coordinates
percent = natural['Latitude'].notna().sum() / len(natural) * 100

print("Theres " + str(percent) + "% of the " + str(len(natural)) + " rows with coordinates")
# Out:
# Theres 17.22728117450288% of the 10762 rows with coordinates

# %% [markdown]
# Discuss: what does it mean for our map if only some events have coordinates? Could this introduce bias?

# %%
# TODO: drop rows where Latitude or Longitude is missing
# Store the result as `geo`
geo = natural.dropna(subset=['Latitude', 'Longitude'])
print(f"Remaining rows: {len(geo)}")
geo['Disaster Type'].value_counts()
# Out:
# Remaining rows: 1854
# Disaster Type
# Flood                  1006
# Earthquake              670
# Storm                   115
# Volcanic activity        48
# Mass movement (wet)      15
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Select and clean the columns we need
#
# We don't need all 47 columns. Let's pick the ones relevant to mapping and severity:
# `Country`, `Disaster Type`, `Start Year`, `Latitude`, `Longitude`, `Total Deaths`, `Total Affected`

# %%
# TODO: select just these columns from `geo`
cols = ['Country', 'Disaster Type', 'Start Year', 'Latitude', 'Longitude', 'Total Deaths', 'Total Affected']
geo = geo[cols]
geo.head()
# Out:
#          Country Disaster Type  Start Year  Latitude  Longitude  Total Deaths  \
# 0        Ecuador    Earthquake        2025     1.084    -79.532           NaN
# 2    Afghanistan    Earthquake        2025    34.519     70.734        2200.0
# 70        Mexico    Earthquake        2026    16.875    -99.336           1.0
# 124  Philippines         Flood        2010     6.780    125.300          27.0
# 125        India         Flood        2010    26.235     92.250           NaN
#
#      Total Affected
# 0            8512.0
# 2         1304600.0
# 70          16152.0
# 124         40000.0
# 125         30000.0

# %%
# TODO: check for nulls in the remaining columns with .isna().sum()
geo.isna().sum()
# Out:
# Country             0
# Disaster Type       0
# Start Year          0
# Latitude            0
# Longitude           0
# Total Deaths      476
# Total Affected    101
# dtype: int64

# %% [markdown]
# `Total Deaths` and `Total Affected` have some missing values. We'll treat missing as 0 for mapping purposes.

# %%
# TODO: fill nulls in 'Total Deaths' and 'Total Affected' with 0 using .fillna(0)
# Then drop any remaining rows missing 'Country' or 'Start Year' with .dropna(subset=[...])
geo['Total Deaths'] = geo['Total Deaths'].fillna(0)
geo['Total Affected'] = geo['Total Affected'].fillna(0)
geo = geo.dropna(subset=['Country', 'Start Year'])
geo.isna().sum()
# Out:
# Country           0
# Disaster Type     0
# Start Year        0
# Latitude          0
# Longitude         0
# Total Deaths      0
# Total Affected    0
# dtype: int64

# %% [markdown]
# ## 4. Quick exploration with pandas
#
# Now that it's clean, let's ask some questions of the data.

# %%
# TODO: which disaster types are most common? (value_counts)
geo['Disaster Type'].value_counts()
# Out:
# Disaster Type
# Flood                  1006
# Earthquake              670
# Storm                   115
# Volcanic activity        48
# Mass movement (wet)      15
# Name: count, dtype: int64

# %%
# TODO: which countries have the most recorded events? (value_counts().head(10))
geo['Country'].value_counts().head(10)
# Out:
# Country
# China                         166
# Indonesia                     133
# Philippines                    79
# India                          77
# Iran (Islamic Republic of)     62
# United States of America       62
# Japan                          45
# Afghanistan                    45
# Pakistan                       42
# Mexico                         38
# Name: count, dtype: int64

# %%
# TODO: filter to events from 2020 onwards and check how many remain
recent = geo[geo['Start Year'] >= 2020]
print(f"Events from 2020 onwards: {len(recent)} out of {len(geo)}")
# Out:
# Events from 2020 onwards: 156 out of 1854

# %% [markdown]
# ## 5. Building the map with Folium
#
# Let's start simple — a blank world map.

# %%
# TODO: create a folium.Map centered roughly on [20, 0] with zoom_start=2
m = folium.Map(location=[20, 0], zoom_start=2, tiles='CartoDB Positron')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78ae1bdd6b77ab354ccba41882db95ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78ae1bdd6b77ab354ccba41882db95ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78ae1bdd6b77ab354ccba41882db95ff = L.map(
#                 &quot;map_78ae1bdd6b77ab354ccba41882db95ff&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57c67db9293311e3ab8e1d03ba727cef = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57c67db9293311e3ab8e1d03ba727cef.addTo(map_78ae1bdd6b77ab354ccba41882db95ff);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now let's add a single marker to check the syntax works.

# %%
# TODO: add a folium.Marker for the first row of `geo`
# Use geo.iloc[0] to get the first row, and its Latitude/Longitude for location
m = folium.Map(location=[20, 0], zoom_start=2)

# your marker code here
folium.Marker(
    location=[geo.iloc[0]['Latitude'], geo.iloc[0]['Longitude']],
    popup=f"{geo.iloc[0]['Disaster Type']} in {geo.iloc[0]['Country']} ({geo.iloc[0]['Start Year']})"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf51332202385f1bb8496fb5073e232b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf51332202385f1bb8496fb5073e232b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf51332202385f1bb8496fb5073e232b = L.map(
#                 &quot;map_bf51332202385f1bb8496fb5073e232b&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_072627f7a92115253bcf95107b27d133 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_072627f7a92115253bcf95107b27d133.addTo(map_bf51332202385f1bb8496fb5073e232b);
#
#
#             var marker_5bf79b6b2087a9c9b7cb522d12e0247c = L.marker(
#                 [1.084, -79.532],
#                 {
# }
#             ).addTo(map_bf51332202385f1bb8496fb5073e232b);
#
#
#         var popup_9cc20d85798776fa1b013f5d9b65f3d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_033f82eb488884aaf900160e106515a3 = $(`&lt;div id=&quot;html_033f82eb488884aaf900160e106515a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Earthquake in Ecuador (2025)&lt;/div&gt;`)[0];
#                 popup_9cc20d85798776fa1b013f5d9b65f3d1.setContent(html_033f82eb488884aaf900160e106515a3);
#
#
#
#         marker_5bf79b6b2087a9c9b7cb522d12e0247c.bindPopup(popup_9cc20d85798776fa1b013f5d9b65f3d1)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 6. Plotting every event
#
# Now let's loop through the dataframe and add a marker for every disaster. We'll:
# - Use `CircleMarker` instead of `Marker` (lighter weight for many points)
# - Colour-code by disaster type
# - Size by `Total Affected` (so bigger circles = bigger impact)
# - Add a popup with details

# %%
# TODO: create a colour_map dictionary mapping each disaster type to a colour
# Folium accepts colour names like 'red', 'blue', 'green', 'purple', 'orange', etc.
disaster_types = geo['Disaster Type'].unique()
colours = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'cadetblue', 'darkgreen', 'pink', 'gray', 'black', 'lightblue', 'darkpurple', 'beige']
colour_map = dict(zip(disaster_types, colours))
colour_map
# Out:
# {'Earthquake': 'red',
#  'Flood': 'blue',
#  'Storm': 'green',
#  'Volcanic activity': 'purple',
#  'Mass movement (wet)': 'orange'}

# %%
import math

m = folium.Map(location=[20, 0], zoom_start=2)

for _, row in geo.iterrows():
    # TODO: compute a radius based on row['Total Affected']
    affected = row['Total Affected']
    # Hint: try 3 + math.log10(affected + 1) * 2  to keep huge numbers from dominating
    radius = 3 + math.log10(affected + 1) * 2

    # TODO: add a folium.CircleMarker using:
    #   - location = [row['Latitude'], row['Longitude']]
    #   - radius = radius
    #   - color = colour_map.get(row['Disaster Type'], 'gray')
    #   - fill=True, fill_opacity=0.6
    #   - popup with disaster type, country, year, deaths, affected
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=radius,
        color=colour_map.get(row['Disaster Type'], 'gray'),
        fill=True,
        fill_opacity=0.6,
        popup=f"{row['Disaster Type']} in {row['Country']} ({row['Start Year']})<br>Deaths: {row['Total Deaths']}<br>Affected: {row['Total Affected']}"
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6307a8061b140caf9dd5fc399017c3cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6307a8061b140caf9dd5fc399017c3cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6307a8061b140caf9dd5fc399017c3cf = L.map(
#                 &quot;map_6307a8061b140caf9dd5fc399017c3cf&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f300d12db8c991802ad0bc6f13ed69d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f300d12db8c991802ad0bc6f13ed69d.addTo(map_6307a8061b140caf9dd5fc399017c3cf);
#
#
#             var circle_marker_8e295bae8276a746ecfe3c3b95ae3126 = L.circleMarker(
#                 [1.084, -79.532],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.860165266784742, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6307a8061b140caf9dd5fc399017c3cf);
#
#
#         var popup_d911a17947e06f9e06c4e3f5fc272a67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6c29ea4966bd807fbb2ef08e9e5ab4c = $(`&lt;div id=&quot;html_e6c29ea4966bd807fbb2ef08e9e5ab4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Earthquake in Ecuador (2025)&lt;br&gt;Deaths: 0.0&lt;br&gt;Affected: 8512.0&lt;/div&gt;`)[0];
#                 popup_d911a17947e06f9e06c4e3f5fc272a67.setContent(html_e6c29ea4966bd807fbb2ef08e9e5ab4c);
#
#
#
#         circle_marker_8e295bae8276a746ecfe3c3b95ae3126.bindPopup(popup_d911a17947e06f9e06c4e3f5fc272a67)
#         ;
#
#
#
#
#             var circle_marker_b47cccae504e54f21402b96edd356c1d = L.circleMarker(
#                 [34.519, 70.734],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.23095541416217, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6307a8061b140caf9dd5fc399017c3cf);
#
#
#         var popup_1aa129172adfa1d804e9e25bb99fecbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7efac9c2b012cace4f29a102dec05507 = $(`&lt;div id=&quot;html_7efac9c2b012cace4f29a102dec05507&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Earthquake in Afghanistan (2025)&lt;br&gt;Deaths: 2200.0&lt;br&gt;Affected: 1304600.0&lt;/div&gt;`)[0];
#                 popup_1aa129172adfa1d804e9e25bb99fecbd.setContent(html_7efac9c2b012cace4f29a102dec05507);
#
#
#
#         circle_marker_b47cccae504e54f21402b96edd356c1d.bindPopup(popup_1aa129172adfa1d804e9e25bb99fecbd)
#         ;
#
#
#
#
#             var circle_marker_6431e7b12f97b0dfbf94a18fb2d3acf6 = L.circleMarker(
#                 [16.875, -99.336],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.41650638614537, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6307a8061b140caf9dd5fc399017c3cf);
#
#
#         var popup_9f883c80c52d383e2e5045c7dcc25ea0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc9b43eb744a91b8cc8d69db4cc677a3 = $(`&lt;div id=&quot;html_bc9b43eb744a91b8cc8d69db4cc677a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Earthquake in Mexico (2026)&lt;br&gt;Deaths: 1.0&lt;br&gt;Affected: 16152.0&lt;/div&gt;`)[0];
#                 popup_9f883c80c52d383e2e5045c7dcc25ea0.setContent(html_bc9b43eb744a91b8cc8d69db4cc677a3);

# %% [markdown]
# ## 7. Mini Challenge (10 minutes)
#
# Pick one (or more!) of these to try:
#
# 1. **Filter to your region** — e.g. `geo[geo['Country'].str.contains('United Kingdom')]` and replot
# 2. **Filter to one disaster type** — e.g. just floods or just earthquakes, and see how the pattern changes
# 3. **Change the colour scheme** — maybe colour by *decade* instead of disaster type
# 4. **Add a legend** — Folium supports custom HTML legends, can you add one showing what each colour means?
# 5. **Save your map** — `m.save('my_climate_map.html')` and open it in a browser
#
# Use the code cell below to experiment!

# %%
# Your code here!

# %% [markdown]
# ## 8. Wrap-up
#
# You've taken a real, messy 16,000-row government dataset and turned it into an interactive map — handling missing data, filtering, and visualisation along the way.
#
# **Where to go next:**
# - Try the [GDIS dataset](https://www.nature.com/articles/s41597-021-00846-6) for subnational geocoding
# - Explore `folium.plugins` — heatmaps, marker clusters, time-based animations (`TimestampedGeoJson`)
# - Combine with [Our World in Data](https://ourworldindata.org/) climate datasets for richer context
#
# Code for this workshop: **[github repo link]**
#
# Thanks for joining!
